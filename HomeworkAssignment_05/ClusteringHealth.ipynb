# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from clustering_health import get_datafile

# %%
data_filepath = get_datafile()
df = pd.read_excel(data_filepath, 'Sheet1')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25830 entries, 0 to 25829
# Data columns (total 57 columns):
# Country Name      25830  non-null values
# Country Code      25830  non-null values
# Indicator Name    25830  non-null values
# Indicator Code    25830  non-null values
# 1960              4259  non-null values
# 1961              3790  non-null values
# 1962              3803  non-null values
# 1963              3808  non-null values
# 1964              3820  non-null values
# 1965              4113  non-null values
# 1966              3866  non-null values
# 1967              3875  non-null values
# 1968              3939  non-null values
# 1969              3939  non-null values
# 1970              4544  non-null values
# 1971              4012  non-null values
# 1972              4036  non-null values
# 1973              4020  non-null values
# 1974              4030  non-null values
# 1975              4391  non-null values
# ...

# %%
df[df['Indicator Code']=='SP.DYN.CBRT.IN'].plot(kind='bar', x='Country Code', y='2010', figsize=(12, 10))
